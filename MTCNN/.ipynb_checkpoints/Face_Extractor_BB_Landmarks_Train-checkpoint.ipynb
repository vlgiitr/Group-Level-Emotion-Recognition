# %% [markdown]
# # Import Modules

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from src import detect_faces, show_bboxes
from PIL import Image

import torch
from torchvision import transforms, datasets
import numpy as np
import os

# %% [markdown]
# # Path Definitions

# %%
dataset_path = '../Dataset/emotiw/'

processed_dataset_path = '../Dataset/FaceCoordinates/'

# %% [markdown]
# # Load Train and Val Dataset

# %%
image_datasets = {x : datasets.ImageFolder(os.path.join(dataset_path, x))
                    for x in ['train', 'val']}

class_names = image_datasets['train'].classes

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
class_names
# Out:
# ['Negative', 'Neutral', 'Positive']

# %%
training_dataset = image_datasets['train']
validation_dataset = image_datasets['val']

# %%
neg_train = sorted(os.listdir(dataset_path + 'train/Negative/'))
neu_train = sorted(os.listdir(dataset_path + 'train/Neutral/'))
pos_train = sorted(os.listdir(dataset_path + 'train/Positive/'))

neg_val = sorted(os.listdir(dataset_path + 'val/Negative/'))
neu_val = sorted(os.listdir(dataset_path + 'val/Neutral/'))
pos_val = sorted(os.listdir(dataset_path + 'val/Positive/'))

# %%
neg_train_filelist = [x.split('.')[0] for x in neg_train]
neu_train_filelist = [x.split('.')[0] for x in neu_train]
pos_train_filelist = [x.split('.')[0] for x in pos_train]

neg_val_filelist = [x.split('.')[0] for x in neg_val]
neu_val_filelist = [x.split('.')[0] for x in neu_val]
pos_val_filelist = [x.split('.')[0] for x in pos_val]

# %%
print(neg_train_filelist[:10])
print(neu_train_filelist[:10])
print(pos_train_filelist[:10])

print(neg_val_filelist[:10])
print(neu_val_filelist[:10])
print(pos_val_filelist[:10])
# Out:
# ['neg_1', 'neg_10', 'neg_100', 'neg_1000', 'neg_1001', 'neg_1002', 'neg_1003', 'neg_1004', 'neg_1005', 'neg_1006']
# ['neu_1', 'neu_10', 'neu_100', 'neu_1000', 'neu_1001', 'neu_1002', 'neu_1003', 'neu_1004', 'neu_1005', 'neu_1006']
# ['pos_1', 'pos_10', 'pos_100', 'pos_1000', 'pos_1001', 'pos_1002', 'pos_1003', 'pos_1004', 'pos_1005', 'pos_1006']
# ['neg_1', 'neg_10', 'neg_100', 'neg_1000', 'neg_1001', 'neg_1002', 'neg_1003', 'neg_1004', 'neg_1005', 'neg_1006']
# ['neu_1', 'neu_10', 'neu_100', 'neu_1000', 'neu_1001', 'neu_1002', 'neu_1003', 'neu_1004', 'neu_1005', 'neu_1006']
# ['pos_1', 'pos_10', 'pos_100', 'pos_1000', 'pos_1001', 'pos_1002', 'pos_1003', 'pos_1004', 'pos_1005', 'pos_1006']

# %%
train_filelist = neg_train_filelist + neu_train_filelist + pos_train_filelist
val_filelist = neg_val_filelist + neu_val_filelist + pos_val_filelist

# %%
print(len(training_dataset))
print(len(validation_dataset))
# Out:
# 9815
# 4346

# %% [markdown]
# # Extract Faces from Image using MTCNN

# %%
for i in range(len(training_dataset)):
    image, label = training_dataset[i]
    print(train_filelist[i])
    try:
        if label == 0:
            if os.path.isfile(processed_dataset_path + 'train/Negative/' + train_filelist[i] + '.npz'):
                print(train_filelist[i] + ' Already present')
                continue
            bounding_boxes, landmarks = detect_faces(image)
            bounding_boxes = np.asarray(bounding_boxes)
            if bounding_boxes.size == 0:
                print('MTCNN model handling empty face condition at ' + train_filelist[i])
            np.savez(processed_dataset_path + 'train/Negative/' + train_filelist[i] , a=bounding_boxes, b=landmarks)

        elif label == 1:
            if os.path.isfile(processed_dataset_path + 'train/Neutral/' + train_filelist[i] + '.npz'):
                print(train_filelist[i] + ' Already present')
                continue
            bounding_boxes, landmarks = detect_faces(image)
            bounding_boxes = np.asarray(bounding_boxes)
            if bounding_boxes.size == 0:
                print('MTCNN model handling empty face condition at ' + train_filelist[i]) 
            np.savez(processed_dataset_path + 'train/Neutral/' + train_filelist[i] , a=bounding_boxes, b=landmarks)

        else:
            if os.path.isfile(processed_dataset_path + 'train/Positive/' + train_filelist[i] + '.npz'):
                print(train_filelist[i] + ' Already present')
                continue
            bounding_boxes, landmarks = detect_faces(image)
            bounding_boxes = np.asarray(bounding_boxes)
            if bounding_boxes.size == 0:
                print('MTCNN model handling empty face condition at ' + train_filelist[i])
            np.savez(processed_dataset_path + 'train/Positive/' + train_filelist[i] , a=bounding_boxes, b=landmarks)
                      
    except ValueError:
        print('No faces detected for ' + train_filelist[i] + ". Also MTCNN failed.")
        if label == 0:
            np.savez(processed_dataset_path + 'train/Negative/' + train_filelist[i] , a=np.zeros(1), b=np.zeros(1))
        elif label == 1:
            np.savez(processed_dataset_path + 'train/Neutral/' + train_filelist[i] , a=np.zeros(1), b=np.zeros(1))
        else:
            np.savez(processed_dataset_path + 'train/Positive/' + train_filelist[i] , a=np.zeros(1), b=np.zeros(1))
        continue

# %%
for i in range(len(validation_dataset)):
    image, label = validation_dataset[i]
    print(val_filelist[i])
    try:
        if label == 0:
            if os.path.isfile(processed_dataset_path + 'val/Negative/' + val_filelist[i] + '.npz'):
                print(val_filelist[i] + ' Already present')
                continue
            bounding_boxes, landmarks = detect_faces(image)
            bounding_boxes = np.asarray(bounding_boxes)
            if bounding_boxes.size == 0:
                print('MTCNN model handling empty face condition at ' + val_filelist[i])
            np.savez(processed_dataset_path + 'val/Negative/' + val_filelist[i] , a=bounding_boxes, b=landmarks)

        elif label == 1:
            if os.path.isfile(processed_dataset_path + 'val/Neutral/' + val_filelist[i] + '.npz'):
                print(val_filelist[i] + ' Already present')
                continue
            bounding_boxes, landmarks = detect_faces(image)
            bounding_boxes = np.asarray(bounding_boxes)
            if bounding_boxes.size == 0:
                print('MTCNN model handling empty face condition at ' + val_filelist[i]) 
            np.savez(processed_dataset_path + 'val/Neutral/' + val_filelist[i] , a=bounding_boxes, b=landmarks)

        else:
            if os.path.isfile(processed_dataset_path + 'val/Positive/' + val_filelist[i] + '.npz'):
                print(val_filelist[i] + ' Already present')
                continue
            bounding_boxes, landmarks = detect_faces(image)
            bounding_boxes = np.asarray(bounding_boxes)
            if bounding_boxes.size == 0:
                print('MTCNN model handling empty face condition at ' + val_filelist[i])
            np.savez(processed_dataset_path + 'val/Positive/' + val_filelist[i] , a=bounding_boxes, b=landmarks)
                      
    except ValueError:
        print('No faces detected for ' + val_filelist[i] + ". Also MTCNN failed.")
        if label == 0:
            np.savez(processed_dataset_path + 'val/Negative/' + val_filelist[i] , a=np.zeros(1), b=np.zeros(1))
        elif label == 1:
            np.savez(processed_dataset_path + 'val/Neutral/' + val_filelist[i] , a=np.zeros(1), b=np.zeros(1))
        else:
            np.savez(processed_dataset_path + 'val/Positive/' + val_filelist[i] , a=np.zeros(1), b=np.zeros(1))
        continue
# Out:
# neg_1
# neg_1 Already present
# neg_10
# neg_10 Already present
# neg_100
# neg_100 Already present
# neg_1000
# neg_1000 Already present
# neg_1001
# neg_1001 Already present
# neg_1002
# neg_1002 Already present
# neg_1003
# neg_1003 Already present
# neg_1004
# neg_1004 Already present
# neg_1005
# neg_1005 Already present
# neg_1006
# neg_1006 Already present
# neg_1007
# neg_1007 Already present
# neg_1008
# neg_1008 Already present
# neg_1009
# neg_1009 Already present
# neg_101
# neg_101 Already present
# neg_1010
# neg_1010 Already present
# neg_1011
# neg_1011 Already present
# neg_1012
# neg_1012 Already present
# neg_1013
# neg_1013 Already present
# neg_1014
# neg_1014 Already present
# neg_1015
# neg_1015 Already present
# neg_1016
# neg_1016 Already present
# neg_1017
# neg_1017 Already present
# neg_1018
# neg_1018 Already present
# neg_1019
# neg_1019 Already present
# neg_102
# neg_102 Already present
# neg_1020
# neg_1020 Already present
# neg_1021
# neg_1021 Already present
# neg_1022
# neg_1022 Already present
# neg_1023
# neg_1023 Already present
# neg_1024
# neg_1024 Already present
# neg_1025
# neg_1025 Already present
# neg_1026
# neg_1026 Already present
# neg_1027
# neg_1027 Already present
# neg_1028
# neg_1028 Already present
# neg_1029
# neg_1029 Already present
# neg_103
# neg_103 Already present
# neg_1030
# neg_1030 Already present
# neg_1031
# neg_1031 Already present
# neg_1032
# neg_1032 Already present
# neg_1033
# neg_1033 Already present
# neg_1034
# neg_1034 Already present
# neg_1035
# neg_1035 Already present
# neg_1036
# neg_1036 Already present
# neg_1037
# neg_1037 Already present
# neg_1038
# neg_1038 Already present
# neg_1039
# neg_1039 Already present
# neg_104
# neg_104 Already present
# neg_1040
# neg_1040 Already present
# neg_1041
# neg_1041 Already present
# neg_1042
# neg_1042 Already present
# neg_1043
# neg_1043 Already present
# neg_1044
# neg_1044 Already present
# neg_1045
# neg_1045 Already present
# neg_1046
# neg_1046 Already present
# neg_1047
# neg_1047 Already present
# neg_1048
# neg_1048 Already present
# neg_1049
# neg_1049 Already present
# neg_105
# neg_105 Already present
# neg_1050
# neg_1050 Already present
# neg_1051
# neg_1051 Already present
# neg_1052
# neg_1052 Already present
# neg_1053
# neg_1053 Already present
# neg_1054
# neg_1054 Already present
# neg_1055
# neg_1055 Already present
# neg_1056
# neg_1056 Already present
# neg_1057
# neg_1057 Already present
# neg_1058
# neg_1058 Already present
# neg_1059
# neg_1059 Already present
# neg_106
# neg_106 Already present
# neg_1060
# neg_1060 Already present
# neg_1061
# neg_1061 Already present
# neg_1062
# neg_1062 Already present
# neg_1063
# neg_1063 Already present
# neg_1064
# neg_1064 Already present
# neg_1065
# neg_1065 Already present
# neg_1066
# neg_1066 Already present
# neg_1067
# neg_1067 Already present
# neg_1068
# neg_1068 Already present
# neg_1069
# neg_1069 Already present
# neg_107
# neg_107 Already present
# neg_1070
# neg_1070 Already present
# neg_1071
# neg_1071 Already present
# neg_1072
# neg_1072 Already present
# neg_1073
# neg_1073 Already present
# neg_1074
# neg_1074 Already present
# neg_1075
# neg_1075 Already present
# neg_1076
# neg_1076 Already present
# neg_1077
# neg_1077 Already present
# neg_1078
# neg_1078 Already present
# neg_1079
# neg_1079 Already present
# neg_108
# neg_108 Already present
# neg_1080
# neg_1080 Already present
# neg_1081
# neg_1081 Already present
# neg_1082
# neg_1082 Already present
# neg_1083
# neg_1083 Already present
# neg_1084
# neg_1084 Already present
# neg_1085
# neg_1085 Already present
# neg_1086
# neg_1086 Already present
# neg_1087
# neg_1087 Already present
# neg_1088
# neg_1088 Already present
# neg_1089
# neg_1089 Already present
# neg_109
# neg_109 Already present
# neg_1090
# neg_1090 Already present
# neg_1091
# neg_1091 Already present
# neg_1092
# neg_1092 Already present
# neg_1093
# neg_1093 Already present
# neg_1094
# neg_1094 Already present
# neg_1095
# neg_1095 Already present
# neg_1096
# neg_1096 Already present
# neg_1097
# neg_1097 Already present
# neg_1098
# neg_1098 Already present
# neg_1099
# neg_1099 Already present
# neg_11
# neg_11 Already present
# neg_110
# neg_110 Already present
# neg_1100
# neg_1100 Already present
# neg_1101
# neg_1101 Already present
# neg_1102
# neg_1102 Already present
# neg_1103
# neg_1103 Already present
# neg_1104
# neg_1104 Already present
# neg_1105
# neg_1105 Already present
# neg_1106
# neg_1106 Already present
# neg_1107
# neg_1107 Already present
# neg_1108
# neg_1108 Already present
# neg_1109
# neg_1109 Already present
# neg_111
# neg_111 Already present
# neg_1110
# neg_1110 Already present
# neg_1111
# neg_1111 Already present
# neg_1112
# neg_1112 Already present
# neg_1113
# neg_1113 Already present
# neg_1114
# neg_1114 Already present
# neg_1115
# neg_1115 Already present
# neg_1116
# neg_1116 Already present
# neg_1117
# neg_1117 Already present
# neg_1118
# neg_1118 Already present
# neg_1119
# neg_1119 Already present
# neg_112
# neg_112 Already present
# neg_1120
# neg_1120 Already present
# neg_1121
# neg_1121 Already present
# neg_1122
# neg_1122 Already present
# neg_1123
# neg_1123 Already present
# neg_1124
# neg_1124 Already present
# neg_1125
# neg_1125 Already present
# neg_1126
# neg_1126 Already present
# neg_1127
# neg_1127 Already present
# neg_1128
# neg_1128 Already present
# neg_1129
# neg_1129 Already present
# neg_113
# neg_113 Already present
# neg_1130
# neg_1130 Already present
# neg_1131
# neg_1131 Already present
# neg_1132
# neg_1132 Already present
# neg_1133
# neg_1133 Already present
# neg_1134
# neg_1134 Already present
# neg_1135
# neg_1135 Already present
# neg_1136
# neg_1136 Already present
# neg_1137
# neg_1137 Already present
# neg_1138
# neg_1138 Already present
# neg_1139
# neg_1139 Already present
# neg_114
# neg_114 Already present
# neg_1140
# neg_1140 Already present
# neg_1141
# neg_1141 Already present
# neg_1142
# neg_1142 Already present
# neg_1143
# neg_1143 Already present
# neg_1144
# neg_1144 Already present
# neg_1145
# neg_1145 Already present
# neg_1146
# neg_1146 Already present
# neg_1147
# neg_1147 Already present
# neg_1148
# neg_1148 Already present
# neg_1149
# neg_1149 Already present
# neg_115
# neg_115 Already present
# neg_1150
# neg_1150 Already present
# neg_1151
# neg_1151 Already present
# neg_1152
# neg_1152 Already present
# neg_1153
# neg_1153 Already present
# neg_1154
# neg_1154 Already present
# neg_1155
# neg_1155 Already present
# neg_1156
# neg_1156 Already present
# neg_1157
# neg_1157 Already present
# neg_1158
# neg_1158 Already present
# neg_1159
# neg_1159 Already present
# neg_116
# neg_116 Already present
# neg_1160
# neg_1160 Already present
# neg_1161
# neg_1161 Already present
# neg_1162
# neg_1162 Already present
# neg_1163
# neg_1163 Already present
# neg_1164
# neg_1164 Already present
# neg_1165
# neg_1165 Already present
# neg_1166
# neg_1166 Already present
# neg_1167
# neg_1167 Already present
# neg_1168
# neg_1168 Already present
# neg_1169
# neg_1169 Already present
# neg_117
# neg_117 Already present
# neg_1170
# neg_1170 Already present
# neg_1171
# neg_1171 Already present
# neg_1172
# neg_1172 Already present
# neg_1173
# neg_1173 Already present
# neg_1174
# neg_1174 Already present
# neg_1175
# neg_1175 Already present
# neg_1176
# neg_1176 Already present
# neg_1177
# neg_1177 Already present
# neg_1178
# neg_1178 Already present
# neg_1179
# neg_1179 Already present
# neg_118
# neg_118 Already present
# neg_1180
# neg_1180 Already present
# neg_1181
# neg_1181 Already present
# neg_1182
# neg_1182 Already present
# neg_1183
# neg_1183 Already present
# neg_1184
# neg_1184 Already present
# neg_1185
# neg_1185 Already present
# neg_1186
# neg_1186 Already present
# neg_1187
# neg_1187 Already present
# neg_1188
# neg_1188 Already present
# neg_1189
# neg_1189 Already present
# neg_119
# neg_119 Already present
# neg_1190
# neg_1190 Already present
# neg_1191
# neg_1191 Already present
# neg_1192
# neg_1192 Already present
# neg_1193
# neg_1193 Already present
# neg_1194
# neg_1194 Already present
# neg_1195
# neg_1195 Already present
# neg_1196
# neg_1196 Already present
# neg_1197
# neg_1197 Already present
# neg_1198
# neg_1198 Already present
# neg_1199
# neg_1199 Already present
# neg_12
# neg_12 Already present
# neg_120
# neg_120 Already present
# neg_1200
# neg_1200 Already present
# neg_1201
# neg_1201 Already present
# neg_1202
# neg_1202 Already present
# neg_1203
# neg_1203 Already present
# neg_1204
# neg_1204 Already present
# neg_1205
# neg_1205 Already present
# neg_1206
# neg_1206 Already present
# neg_1207
# neg_1207 Already present
# neg_1208
# neg_1208 Already present
# neg_1209
# neg_1209 Already present
# neg_121
# neg_121 Already present
# neg_1210
# neg_1210 Already present
# neg_1211
# neg_1211 Already present
# neg_1212
# neg_1212 Already present
# neg_1213
# neg_1213 Already present
# neg_1214
# neg_1214 Already present
# neg_1215
# neg_1215 Already present
# neg_1216
# neg_1216 Already present
# neg_1217
# neg_1217 Already present
# neg_1218
# neg_1218 Already present
# neg_1219
# neg_1219 Already present
# neg_122
# neg_122 Already present
# neg_1220
# neg_1220 Already present
# neg_1221
# neg_1221 Already present
# neg_1222
# neg_1222 Already present
# neg_1223
# neg_1223 Already present
# neg_1224
# neg_1224 Already present
# neg_1225
# neg_1225 Already present
# neg_1226
# neg_1226 Already present
# neg_1227
# neg_1227 Already present
# neg_1228
# neg_1228 Already present
# neg_1229
# neg_1229 Already present
# neg_123
# neg_123 Already present
# neg_1230
# neg_1230 Already present
# neg_1231
# neg_1231 Already present
# neg_124
# neg_124 Already present
# neg_125
# neg_125 Already present
# neg_126
# neg_126 Already present
# neg_127
# neg_127 Already present
# neg_128
# neg_128 Already present
# neg_129
# neg_129 Already present
# neg_13
# neg_13 Already present
# neg_130
# neg_130 Already present
# neg_131
# neg_131 Already present
# neg_132
# neg_132 Already present
# neg_133
# neg_133 Already present
# neg_134
# neg_134 Already present
# neg_135
# neg_135 Already present
# neg_136
# neg_136 Already present
# neg_137
# neg_137 Already present
# neg_138
# neg_138 Already present
# neg_139
# neg_139 Already present
# neg_14
# neg_14 Already present
# neg_140
# neg_140 Already present
# neg_141
# neg_141 Already present
# neg_142
# neg_142 Already present
# neg_143
# neg_143 Already present
# neg_144
# neg_144 Already present
# neg_145
# neg_145 Already present
# neg_146
# neg_146 Already present
# neg_147
# neg_147 Already present
# neg_148
# neg_148 Already present
# neg_149
# neg_149 Already present
# neg_15
# neg_15 Already present
# neg_150
# neg_150 Already present
# neg_151
# neg_151 Already present
# neg_152
# neg_152 Already present
# neg_153
# neg_153 Already present
# neg_154
# neg_154 Already present
# neg_155
# neg_155 Already present
# neg_156
# neg_156 Already present
# neg_157
# neg_157 Already present
# neg_158
# neg_158 Already present
# neg_159
# neg_159 Already present
# neg_16
# neg_16 Already present
# neg_160
# neg_160 Already present
# neg_161
# neg_161 Already present
# neg_162
# neg_162 Already present
# neg_163
# neg_163 Already present
# neg_164
# neg_164 Already present
# neg_165
# neg_165 Already present
# neg_166
# neg_166 Already present
# neg_167
# neg_167 Already present
# neg_168
# neg_168 Already present
# neg_169
# neg_169 Already present
# neg_17
# neg_17 Already present
# neg_170
# neg_170 Already present
# neg_171
# neg_171 Already present
# neg_172
# neg_172 Already present
# neg_173
# neg_173 Already present
# neg_174
# neg_174 Already present
# neg_175
# neg_175 Already present
# neg_176
# neg_176 Already present
# neg_177
# neg_177 Already present
# neg_178
# neg_178 Already present
# neg_179
# neg_179 Already present
# neg_18
# neg_18 Already present
# neg_180
# neg_180 Already present
# neg_181
# neg_181 Already present
# neg_182
# neg_182 Already present
# neg_183
# neg_183 Already present
# neg_184
# neg_184 Already present
# neg_185
# neg_185 Already present
# neg_186
# neg_186 Already present
# neg_187
# neg_187 Already present
# neg_188
# neg_188 Already present
# neg_189
# neg_189 Already present
# neg_19
# neg_19 Already present
# neg_190
# neg_190 Already present
# neg_191
# neg_191 Already present
# neg_192
# neg_192 Already present
# neg_193
# neg_193 Already present
# neg_194
# neg_194 Already present
# neg_195
# neg_195 Already present
# neg_196
# neg_196 Already present
# neg_197
# neg_197 Already present
# neg_198
# neg_198 Already present
# neg_199
# neg_199 Already present
# neg_2
# neg_2 Already present
# neg_20
# neg_20 Already present
# neg_200
# neg_200 Already present
# neg_201
# neg_201 Already present
# neg_202
# neg_202 Already present
# neg_203
# neg_203 Already present
# neg_204
# neg_204 Already present
# neg_205
# neg_205 Already present
# neg_206
# neg_206 Already present
# neg_207
# neg_207 Already present
# neg_208
# neg_208 Already present
# neg_209
# neg_209 Already present
# neg_21
# neg_21 Already present
# neg_210
# neg_210 Already present
# neg_211
# neg_211 Already present
# neg_212
# neg_212 Already present
# neg_213
# neg_213 Already present
# neg_214
# neg_214 Already present
# neg_215
# neg_215 Already present
# neg_216
# neg_216 Already present
# neg_217
# neg_217 Already present
# neg_218
# neg_218 Already present
# neg_219
# neg_219 Already present
# neg_22
# neg_22 Already present
# neg_220
# neg_220 Already present
# neg_221
# neg_221 Already present
# neg_222
# neg_222 Already present
# neg_223
# neg_223 Already present
# neg_224
# neg_224 Already present
# neg_225
# neg_225 Already present
# neg_226
# neg_226 Already present
# neg_227
# neg_227 Already present
# neg_228
# neg_228 Already present
# neg_229
# neg_229 Already present
# neg_23
# neg_23 Already present
# neg_230
# neg_230 Already present
# neg_231
# neg_231 Already present
# neg_232
# neg_232 Already present
# neg_233
# neg_233 Already present
# neg_234
# neg_234 Already present
# neg_235
# neg_235 Already present
# neg_236
# neg_236 Already present
# neg_237
# neg_237 Already present
# neg_238
# neg_238 Already present
# neg_239
# neg_239 Already present
# neg_24
# neg_24 Already present
# neg_240
# neg_240 Already present
# neg_241
# neg_241 Already present
# neg_242
# neg_242 Already present
# neg_243
# neg_243 Already present
# neg_244
# neg_244 Already present
# neg_245
# neg_245 Already present
# neg_246
# neg_246 Already present
# neg_247
# neg_247 Already present
# neg_248
# neg_248 Already present
# neg_249
# neg_249 Already present
# neg_25
# neg_25 Already present
# neg_250
# neg_250 Already present
# neg_251
# neg_251 Already present
# neg_252
# neg_252 Already present
# neg_253
# neg_253 Already present
# neg_254
# neg_254 Already present
# neg_255
# neg_255 Already present
# neg_256
# neg_256 Already present
# neg_257
# neg_257 Already present
# neg_258
# neg_258 Already present
# neg_259
# neg_259 Already present
# neg_26
# neg_26 Already present
# neg_260
# neg_260 Already present
# neg_261
# neg_261 Already present
# neg_262
# neg_262 Already present
# neg_263
# neg_263 Already present
# neg_264
# neg_264 Already present
# neg_265
# neg_265 Already present
# neg_266
# neg_266 Already present
# neg_267
# neg_267 Already present
# neg_268
# neg_268 Already present
# neg_269
# neg_269 Already present
# neg_27
# neg_27 Already present
# neg_270
# neg_270 Already present
# neg_271
# neg_271 Already present
# neg_272
# neg_272 Already present
# neg_273
# neg_273 Already present
# neg_274
# neg_274 Already present
# neg_275
# neg_275 Already present
# neg_276
# neg_276 Already present
# neg_277
# neg_277 Already present
# neg_278
# neg_278 Already present
# neg_279
# neg_279 Already present
# neg_28
# neg_28 Already present
# neg_280
# neg_280 Already present
# neg_281
# neg_281 Already present
# neg_282
# neg_282 Already present
# neg_283
# neg_283 Already present
# neg_284
# neg_284 Already present
# neg_285
# neg_285 Already present
# neg_286
# neg_286 Already present
# neg_287
# neg_287 Already present
# neg_288
# neg_288 Already present
# neg_289
# neg_289 Already present
# neg_29
# neg_29 Already present
# neg_290
# neg_290 Already present
# neg_291
# neg_291 Already present
# neg_292
# neg_292 Already present
# neg_293
# neg_293 Already present
# neg_294
# neg_294 Already present
# neg_295
# neg_295 Already present
# neg_296
# neg_296 Already present
# neg_297
# neg_297 Already present
# neg_298
# neg_298 Already present
# neg_299
# neg_299 Already present
# neg_3
# neg_3 Already present
# neg_30
# neg_30 Already present
# neg_300
# neg_300 Already present
# neg_301
# neg_301 Already present
# neg_302
# neg_302 Already present
# neg_303
# neg_303 Already present
# neg_304
# neg_304 Already present
# neg_305
# neg_305 Already present
# neg_306
# neg_306 Already present
# neg_307
# neg_307 Already present
# neg_308
# neg_308 Already present
# neg_309
# neg_309 Already present
# neg_31
# neg_31 Already present
# neg_310
# neg_310 Already present
# neg_311
# neg_311 Already present
# neg_312
# neg_312 Already present
# neg_313
# neg_313 Already present
# neg_314
# neg_314 Already present
# neg_315
# neg_315 Already present
# neg_316
# neg_316 Already present
# neg_317
# neg_317 Already present
# neg_318
# neg_318 Already present
# neg_319
# neg_319 Already present
# neg_32
# neg_32 Already present
# neg_320
# neg_320 Already present
# neg_321
# neg_321 Already present
# neg_322
# neg_322 Already present
# neg_323
# neg_323 Already present
# neg_324
# neg_324 Already present
# neg_325
# neg_325 Already present
# neg_326
# neg_326 Already present
# neg_327
# neg_327 Already present
# neg_328
# neg_328 Already present
# neg_329
# neg_329 Already present
# neg_33
# neg_33 Already present
# neg_330
# neg_330 Already present
# neg_331
# neg_331 Already present
# neg_332
# neg_332 Already present
# neg_333
# neg_333 Already present
# neg_334
# neg_334 Already present
# neg_335
# neg_335 Already present
# neg_336
# neg_336 Already present
# neg_337
# neg_337 Already present
# neg_338
# neg_338 Already present
# neg_339
# neg_339 Already present
# neg_34
# neg_34 Already present
# neg_340
# neg_340 Already present
# neg_341
# neg_341 Already present
# neg_342
# neg_342 Already present
# neg_343
# neg_343 Already present
# neg_344
# neg_344 Already present
# neg_345
# neg_345 Already present
# neg_346
# neg_346 Already present
# neg_347
# neg_347 Already present
# neg_348
# neg_348 Already present
# neg_349
# neg_349 Already present
# neg_35
# neg_35 Already present
# neg_350
# neg_350 Already present
# neg_351
# neg_351 Already present
# neg_352
# neg_352 Already present
# neg_353
# neg_353 Already present
# neg_354
# neg_354 Already present
# neg_355
# neg_355 Already present
# neg_356
# neg_356 Already present
# neg_357
# neg_357 Already present
# neg_358
# neg_358 Already present
# neg_359
# neg_359 Already present
# neg_36
# neg_36 Already present
# neg_360
# neg_360 Already present
# neg_361
# neg_361 Already present
# neg_362
# neg_362 Already present
# neg_363
# neg_363 Already present
# neg_364
# neg_364 Already present
# neg_365
# neg_365 Already present
# neg_366
# neg_366 Already present
# neg_367
# neg_367 Already present
# neg_368
# neg_368 Already present
# neg_369
# neg_369 Already present
# neg_37
# neg_37 Already present
# neg_370
# neg_370 Already present
# neg_371
# neg_371 Already present
# neg_372
# neg_372 Already present
# neg_373
# neg_373 Already present
# neg_374
# neg_374 Already present
# neg_375
# neg_375 Already present
# neg_376
# neg_376 Already present
# neg_377
# neg_377 Already present
# neg_378
# neg_378 Already present
# neg_379
# neg_379 Already present
# neg_38
# neg_38 Already present
# neg_380
# neg_380 Already present
# neg_381
# neg_381 Already present
# neg_382
# neg_382 Already present
# neg_383
# neg_383 Already present
# neg_384
# neg_384 Already present
# neg_385
# neg_385 Already present
# neg_386
# neg_386 Already present
# neg_387
# neg_387 Already present
# neg_388
# neg_388 Already present
# neg_389
# neg_389 Already present
# neg_39
# neg_39 Already present
# neg_390
# neg_390 Already present
# neg_391
# neg_391 Already present
# neg_392
# neg_392 Already present
# neg_393
# neg_393 Already present
# neg_394
# neg_394 Already present
# neg_395
# neg_395 Already present
# neg_396
# neg_396 Already present
# neg_397
# neg_397 Already present
# neg_398
# neg_398 Already present
# neg_399
# neg_399 Already present
# neg_4
# neg_4 Already present
# neg_40
# neg_40 Already present
# neg_400
# neg_400 Already present
# neg_401
# neg_401 Already present
# neg_402
# neg_402 Already present
# neg_403
# neg_403 Already present
# neg_404
# neg_404 Already present
# neg_405
# neg_405 Already present
# neg_406
# neg_406 Already present
# neg_407
# neg_407 Already present
# neg_408
# neg_408 Already present
# neg_409
# neg_409 Already present
# neg_41
# neg_41 Already present
# neg_410
# neg_410 Already present
# neg_411
# neg_411 Already present
# neg_412
# neg_412 Already present
# neg_413
# neg_413 Already present
# neg_414
# neg_414 Already present
# neg_415
# neg_415 Already present
# neg_416
# neg_416 Already present
# neg_417
# neg_417 Already present
# neg_418
# neg_418 Already present
# neg_419
# neg_419 Already present
# neg_42
# neg_42 Already present
# neg_420
# neg_420 Already present
# neg_421
# neg_421 Already present
# neg_422
# neg_422 Already present
# neg_423
# neg_423 Already present
# neg_424
# neg_424 Already present
# neg_425
# neg_425 Already present
# neg_426
# neg_426 Already present
# neg_427
# neg_427 Already present
# neg_428
# neg_428 Already present
# neg_429
# neg_429 Already present
# neg_43
# neg_43 Already present
# neg_430
# neg_430 Already present
# neg_431
# neg_431 Already present
# neg_432
# neg_432 Already present
# neg_433
# neg_433 Already present
# neg_434
# neg_434 Already present
# neg_435
# neg_435 Already present
# neg_436
# neg_436 Already present
# neg_437
# neg_437 Already present
# neg_438
# neg_438 Already present
# neg_439
# neg_439 Already present
# neg_44
# neg_44 Already present
# neg_440
# neg_440 Already present
# neg_441
# neg_441 Already present
# neg_442
# neg_442 Already present
# neg_443
# neg_443 Already present
# neg_444
# neg_444 Already present
# neg_445
# neg_445 Already present
# neg_446
# neg_446 Already present
# neg_447
# neg_447 Already present
# neg_448
# neg_448 Already present
# neg_449
# neg_449 Already present
# neg_45
# neg_45 Already present
# neg_450
# neg_450 Already present
# neg_451
# neg_451 Already present
# neg_452
# neg_452 Already present
# neg_453
# neg_453 Already present
# neg_454
# neg_454 Already present
# neg_455
# neg_455 Already present
# neg_456
# neg_456 Already present
# neg_457
# neg_457 Already present
# neg_458
# neg_458 Already present
# neg_459
# neg_459 Already present
# neg_46
# neg_46 Already present
# neg_460
# neg_460 Already present
# neg_461
# neg_461 Already present
# neg_462
# neg_462 Already present
# neg_463
# neg_463 Already present
# neg_464
# neg_464 Already present
# neg_465
# neg_465 Already present
# neg_466
# neg_466 Already present
# neg_467
# neg_467 Already present
# neg_468
# neg_468 Already present
# neg_469
